# %% [markdown]
# ## Parsing Web Page

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as BS
page = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BS(page.content, "html.parser")

# %%
s1 = soup.find("tbody")
s2 = s1.find_all("tr")

# %%
s3 =[]
for i in s2:
    s3.append(i.get_text().replace("\n\n", ",").replace("\n",""))
s4 = []
for x in s3:
    s4.append(x.split(","))

# %% [markdown]
# ## Data Frame

# %%
data = pd.DataFrame()

# %%
Postal_Code = []
Borough = []
Neighborhood = []
for x in s4:
    Postal_Code.append(x[0])
    Borough.append(x[1])
    Neighborhood.append(x[2])
data["Postal_Code"]=Postal_Code
data["Borough"]=Borough
data["Neighborhood"]=Neighborhood

# %%
data
# Out:
#      Postal_Code       Borough      Neighborhood
# 0    Postal Code       Borough      Neighborhood
# 1            M1A  Not assigned      Not assigned
# 2            M2A  Not assigned      Not assigned
# 3            M3A    North York         Parkwoods
# 4            M4A    North York  Victoria Village
# ..           ...           ...               ...
# 176          M5Z  Not assigned      Not assigned
# 177          M6Z  Not assigned      Not assigned
# 178          M7Z  Not assigned      Not assigned
# 179          M8Z     Etobicoke         Mimico NW
# 180          M9Z  Not assigned      Not assigned
#
# [181 rows x 3 columns]

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
data.drop([0], axis=0, inplace=True) 
data2 = data[data["Borough"]!="Not assigned"]
data2
# Out:
#     Postal_Code           Borough                           Neighborhood
# 3           M3A        North York                              Parkwoods
# 4           M4A        North York                       Victoria Village
# 5           M5A  Downtown Toronto                            Regent Park
# 6           M6A        North York                         Lawrence Manor
# 7           M7A  Downtown Toronto                           Queen's Park
# ..          ...               ...                                    ...
# 161         M8X         Etobicoke                           The Kingsway
# 166         M4Y  Downtown Toronto                   Church and Wellesley
# 169         M7Y      East Toronto  Business reply mail Processing Centre
# 170         M8Y         Etobicoke                         Old Mill South
# 179         M8Z         Etobicoke                              Mimico NW
#
# [103 rows x 3 columns]

# %% [markdown]
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.

# %%
for x in data2["Neighborhood"]:
    if x=="Not assigned":
        print("Clean data")
print("All the values in Neighborhood are assigned")
# Out:
# All the values in Neighborhood are assigned

# %%
data2.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Geocoder package

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# %%
lat = []
lon = []
for x in range(0,len(data2)):
    geolocator = Nominatim(user_agent="ny_explorer")
    try:
        location = geolocator.geocode("Canada Toronto " + data2.iloc[x,2])
        latitude = location.latitude
        longitude = location.longitude
        lat.append(location.latitude)
        lon.append(location.longitude)
        print('The geograpical coordinates: {}, {}, {}, {}.'.format(x, data2.iloc[x,2],latitude, longitude))
    
    except:
        location = geolocator.geocode("Canada Toronto " + data2.iloc[x,1])
        latitude = location.latitude
        longitude = location.longitude
        lat.append(location.latitude)
        lon.append(location.longitude)
        print('The geograpical coordinates: {}, {}, {}, {}.'.format(x, data2.iloc[x,2],latitude, longitude))
# Out:
# The geograpical coordinates: 0, Parkwoods, 43.7587999, -79.3201966.
# The geograpical coordinates: 1, Victoria Village, 43.732658, -79.3111892.
# The geograpical coordinates: 2, Regent Park, 43.6607056, -79.3604569.
# The geograpical coordinates: 3, Lawrence Manor, 43.7220788, -79.4375067.
# The geograpical coordinates: 4, Queen's Park, 43.659659, -79.3903399.
# The geograpical coordinates: 5, Islington Avenue, 43.6794838, -79.5389092.
# The geograpical coordinates: 6, Malvern, 43.8091955, -79.2217008.
# The geograpical coordinates: 7, Don Mills, 43.775347, -79.3459439.
# The geograpical coordinates: 8, Parkview Hill, 43.6534817, -79.3839347.
# The geograpical coordinates: 9, Garden District, 43.6564995, -79.3771141.
# The geograpical coordinates: 10, Glencairn, 43.7087117, -79.4406853.
# The geograpical coordinates: 11, West Deane Park, 43.6631995, -79.5685684.
# The geograpical coordinates: 12, Rouge Hill, 43.7802711, -79.1304992.
# The geograpical coordinates: 13, Don Mills, 43.775347, -79.3459439.
# The geograpical coordinates: 14, Woodbine Heights, 43.6999302, -79.3191316.
# The geograpical coordinates: 15, St. James Town, 43.6694032, -79.3727041.
# The geograpical coordinates: 16, Humewood-Cedarvale, 43.690844350000006, -79.4249313241846.
# The geograpical coordinates: 17, Eringate, 43.6622732, -79.5765162.
# The geograpical coordinates: 18, Guildwood, 43.7552251, -79.1982293.
# The geograpical coordinates: 19, The Beaches, 43.6710244, -79.296712.
# The geograpical coordinates: 20, Berczy Park, 43.64798435, -79.37539591138858.
# The geograpical coordinates: 21, Caledonia-Fairbanks, 43.67910515, -79.49118414007154.
# The geograpical coordinates: 22, Woburn, 43.7598243, -79.2252908.
# The geograpical coordinates: 23, Leaside, 43.7047983, -79.3680904.
# The geograpical coordinates: 24, Central Bay Street, 43.6607076, -79.3858018.
# The geograpical coordinates: 25, Christie, 43.6641106, -79.4184051.
# The geograpical coordinates: 26, Cedarbrae, 43.75646655, -79.22669244258802.
# The geograpical coordinates: 27, Hillcrest Village, 43.7996637, -79.3650189.
# The geograpical coordinates: 28, Bathurst Manor, 43.76389295, -79.45636693710946.
# The geograpical coordinates: 29, Thorncliffe Park, 43.704553, -79.3454074.
# The geograpical coordinates: 30, Richmond, 43.8125891, -79.2633703893962.
# The geograpical coordinates: 31, Dufferin, 43.6602019, -79.4357191.
# The geograpical coordinates: 32, Scarborough Village, 43.7437422, -79.2116324.
# The geograpical coordinates: 33, Fairview, 43.6534817, -79.3839347.
# The geograpical coordinates: 34, Northwood Park, 43.7541351, -79.50448.
# The geograpical coordinates: 35, East Toronto, 43.6534817, -79.3839347.
# The geograpical coordinates: 36, Harbourfront East, 43.6247901, -79.3934918.
# The geograpical coordinates: 37, Little Portugal, 43.64741325, -79.43111632546047.
# The geograpical coordinates: 38, Kennedy Park, 43.724878, -79.2539688.
# The geograpical coordinates: 39, Bayview Village, 43.7691966, -79.3766617.
# The geograpical coordinates: 40, Downsview, 43.7492988, -79.462248.
# The geograpical coordinates: 41, The Danforth West, 43.6789439, -79.3448597.
# The geograpical coordinates: 42, Toronto Dominion Centre, 43.6473768, -79.3813719429129.
# The geograpical coordinates: 43, Brockton, 43.6509173, -79.4400216.
# The geograpical coordinates: 44, Golden Mile, 43.7278414, -79.2876217.
# The geograpical coordinates: 45, York Mills, 43.7440391, -79.406657.
# The geograpical coordinates: 46, Downsview, 43.7492988, -79.462248.
# The geograpical coordinates: 47, India Bazaar, 43.6722231, -79.3235032.
# The geograpical coordinates: 48, Commerce Court, 43.64809515, -79.37902543099575.
# The geograpical coordinates: 49, North Park, 43.7186899, -79.4775337.
# The geograpical coordinates: 50, Humber Summit, 43.7600778, -79.5717598.
# The geograpical coordinates: 51, Cliffside, 43.7111699, -79.2481769.
# The geograpical coordinates: 52, Willowdale, 43.7615095, -79.4109234.
# The geograpical coordinates: 53, Downsview, 43.7492988, -79.462248.
# The geograpical coordinates: 54, Studio District, 43.6534817, -79.3839347.
# The geograpical coordinates: 55, Bedford Park, 43.7373876, -79.4109253.
# The geograpical coordinates: 56, Del Ray, 43.6890238, -79.493985.
# The geograpical coordinates: 57, Humberlea, 43.7213166, -79.5331605.
# The geograpical coordinates: 58, Birch Cliff, 43.6918051, -79.2644935.
# The geograpical coordinates: 59, Willowdale, 43.7615095, -79.4109234.
# The geograpical coordinates: 60, Downsview, 43.7492988, -79.462248.
# The geograpical coordinates: 61, Lawrence Park, 43.729199, -79.4032525.
# The geograpical coordinates: 62, Roselawn, 43.6994563, -79.4546164.
# The geograpical coordinates: 63, Runnymede, 43.6517026, -79.4759978.
# The geograpical coordinates: 64, Weston, 43.7001608, -79.5162474.
# The geograpical coordinates: 65, Dorset Park, 43.7528467, -79.282067.
# The geograpical coordinates: 66, York Mills West, 43.7440391, -79.406657.
# The geograpical coordinates: 67, Davisville North, 43.697936, -79.3972908.
# The geograpical coordinates: 68, Forest Hill North & West, 43.701028, -79.4255998.
# The geograpical coordinates: 69, High Park, 43.6538668, -79.4668644.
# The geograpical coordinates: 70, Westmount, 43.6936399, -79.5210426.
# The geograpical coordinates: 71, Wexford, 43.7453767, -79.2947155.
# The geograpical coordinates: 72, Willowdale, 43.7615095, -79.4109234.
# The geograpical coordinates: 73, North Toronto West, 43.6534817, -79.3839347.
# The geograpical coordinates: 74, The Annex, 43.6703377, -79.407117.
# The geograpical coordinates: 75, Parkdale, 43.6404954, -79.4368965.
# The geograpical coordinates: 76, Canada Post Gateway Processing Centre, 43.5483881, -79.66278143853629.
# The geograpical coordinates: 77, Kingsview Village, 43.6995391, -79.5563459.
# The geograpical coordinates: 78, Agincourt, 43.7853531, -79.2785494.
# The geograpical coordinates: 79, Davisville, 43.697936, -79.3972908.
# The geograpical coordinates: 80, University of Toronto, 43.663461999999996, -79.39775965337452.
# The geograpical coordinates: 81, Runnymede, 43.6517026, -79.4759978.
# The geograpical coordinates: 82, Clarks Corners, 43.7964095, -79.2977951.
# The geograpical coordinates: 83, Moore Park, 43.6903876, -79.3832965.
# The geograpical coordinates: 84, Kensington Market, 43.6552136, -79.4022604.
# The geograpical coordinates: 85, Milliken, 43.8231743, -79.3017626.
# The geograpical coordinates: 86, Summerhill West, 43.6816776, -79.3905037.
# The geograpical coordinates: 87, CN Tower, 43.6425637, -79.38708718320467.
# The geograpical coordinates: 88, New Toronto, 43.6007625, -79.505264.
# The geograpical coordinates: 89, South Steeles, 43.8161778, -79.3145378.
# The geograpical coordinates: 90, Steeles West, 43.8161778, -79.3145378.
# The geograpical coordinates: 91, Rosedale, 43.6783556, -79.3807457.
# The geograpical coordinates: 92, Stn A PO Boxes, 43.6541737, -79.38081164513409.
# The geograpical coordinates: 93, Alderwood, 43.6017173, -79.5452325.
# The geograpical coordinates: 94, Northwest, 43.6465466, -79.4195263.
# The geograpical coordinates: 95, Upper Rouge, 43.8049304, -79.1658374.
# The geograpical coordinates: 96, St. James Town, 43.6694032, -79.3727041.
# The geograpical coordinates: 97, First Canadian Place, 43.6487681, -79.38169179283025.
# The geograpical coordinates: 98, The Kingsway, 43.6473811, -79.5113328.
# The geograpical coordinates: 99, Church and Wellesley, 43.6655242, -79.3838011.
# The geograpical coordinates: 100, Business reply mail Processing Centre, 43.6534817, -79.3839347.
# The geograpical coordinates: 101, Old Mill South, 43.649826, -79.4943338.
# The geograpical coordinates: 102, Mimico NW, 43.6166773, -79.4968048.

# %%
data2["latitude"]=lat
data2["longitude"]=lon
# Out:
# C:\Users\PcHome\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\PcHome\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data2.head(22)
# Out:
#    Postal_Code           Borough         Neighborhood   latitude  longitude
# 3          M3A        North York            Parkwoods  43.758800 -79.320197
# 4          M4A        North York     Victoria Village  43.732658 -79.311189
# 5          M5A  Downtown Toronto          Regent Park  43.660706 -79.360457
# 6          M6A        North York       Lawrence Manor  43.722079 -79.437507
# 7          M7A  Downtown Toronto         Queen's Park  43.659659 -79.390340
# 9          M9A         Etobicoke     Islington Avenue  43.679484 -79.538909
# 10         M1B       Scarborough              Malvern  43.809196 -79.221701
# 12         M3B        North York            Don Mills  43.775347 -79.345944
# 13         M4B         East York        Parkview Hill  43.653482 -79.383935
# 14         M5B  Downtown Toronto      Garden District  43.656500 -79.377114
# 15         M6B        North York            Glencairn  43.708712 -79.440685
# 18         M9B         Etobicoke      West Deane Park  43.663199 -79.568568
# 19         M1C       Scarborough           Rouge Hill  43.780271 -79.130499
# 21         M3C        North York            Don Mills  43.775347 -79.345944
# 22         M4C         East York     Woodbine Heights  43.699930 -79.319132
# 23         M5C  Downtown Toronto       St. James Town  43.669403 -79.372704
# 24         M6C              York   Humewood-Cedarvale  43.690844 -79.424931
# 27         M9C         Etobicoke             Eringate  43.662273 -79.576516
# 28         M1E       Scarborough            Guildwood  43.755225 -79.198229
# 31         M4E      East Toronto          The Beaches  43.671024 -79.296712
# 32         M5E  Downtown Toronto          Berczy Park  43.647984 -79.375396
# 33         M6E              York  Caledonia-Fairbanks  43.679105 -79.491184

# %% [markdown]
# ## Map Visulation

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
import folium

# %%
# create map of Toronto latitude and longitude values
map_toronto = folium.Map(location=[43.6534817, -79.3839347], zoom_start=12)

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

for lat, lng, in zip(data2.latitude, data2.longitude):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=3, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='red',
            fill_opacity=0.6
        )
    )
# add incidents to map
map_toronto.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

data3 = data2[data2["Borough"]=="Central Toronto"]

for lat, lng, in zip(data3.latitude, data3.longitude):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='blue',
            fill=True,
            fill_color='red',
            fill_opacity=0.6
        )
    )

data4 = data2[data2["Borough"]!="Central Toronto"]   
for lat, lng, in zip(data4.latitude, data4.longitude):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )        

# add incidents to map
map_toronto.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create map of Toronto latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(data3['latitude'], data3['longitude'], data3['Borough'], data3['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        #radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='orange',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
for lat, lng, borough, neighborhood in zip(data4['latitude'], data4['longitude'], data4['Borough'], data4['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        #radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
